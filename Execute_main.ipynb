# %%
# !python -m unittest Testbench.py
# Out:
# Testing adding new course (TEST100)...
# Course 'TEST100' added successfully!
#
# Testing adding two professors...
# Professor 'prof_test@mycsu.edu' added successfully!
# Professor 'prof_test2@mycsu.edu' already exists!
#
# Testing adding two students...
#
# Available Courses:
# 1. DATA200
# 2. MATH101
# 3. ENG202
# 4. PHY303
# 5. CHEM404
# 6. DATA300
# 7. TEST200
# 8. TEST100
# Student added successfully!
# Student already exists!
#
# Testing deleting course 'TEST100'...
# Course deleted successfully!
#
# Testing deleting professor 'prof_test@mycsu.edu'...
# Professor 'prof_test@mycsu.edu' deleted successfully from professors.csv and login.csv!
#
# Testing deleting student 'student_test1@mycsu.edu'...
# Student 'student_test1@mycsu.edu' deleted successfully from students.csv and login.csv!
#
# Testing encryption/decryption for 'student_0@mycsu.edu'...
# Encrypted password: VwxghqwSdvv123
# Decrypted password: StudentPass123
#
# Testing existing professor login...
# ...
